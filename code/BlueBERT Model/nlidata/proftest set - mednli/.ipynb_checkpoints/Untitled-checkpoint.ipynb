# %%
import pandas as pd
import numpy as np

# %%
testset = pd.read_json("mednli.jsonl", lines = True)

# %%
testgroundtruth = pd.read_csv("mednli.csv")

# %%
testgroundtruth
# Out:
#                                          pair_id          label
# 0    mediqa-6784509e-5ca1-11e9-8844-f45c89b91419     entailment
# 1    mediqa-678582f4-5ca1-11e9-af66-f45c89b91419  contradiction
# 2    mediqa-67858838-5ca1-11e9-ad79-f45c89b91419        neutral
# 3    mediqa-67858ba8-5ca1-11e9-8a1f-f45c89b91419     entailment
# 4    mediqa-67858f54-5ca1-11e9-baa4-f45c89b91419  contradiction
# ..                                           ...            ...
# 400  mediqa-6789e518-5ca1-11e9-aca6-f45c89b91419  contradiction
# 401  mediqa-6789e72c-5ca1-11e9-ad15-f45c89b91419        neutral
# 402  mediqa-6789eab6-5ca1-11e9-a462-f45c89b91419     entailment
# 403  mediqa-6789ed06-5ca1-11e9-b15f-f45c89b91419  contradiction
# 404  mediqa-6789ef9a-5ca1-11e9-a2f1-f45c89b91419        neutral
#
# [405 rows x 2 columns]

# %%
testset = testset.merge(testgroundtruth, how = "inner", left_on = "pairID", right_on = "pair_id")

# %%
testset = testset.drop(["gold_label"], axis = 1)

# %%
testset = testset.reset_index()

# %%
columnsneeded = ["label","index", "sentence1", "sentence2"]

# %%
testset[columnsneeded].to_csv("test.tsv", sep = "\t",index = False)

# %%
testset
# Out:
#      index                                    sentence2_parse  \
# 0        0  (ROOT (S (NP (PRP she)) (VP (VBD appeared) (AD...
# 1        1  (ROOT (S (NP (PRP she)) (VP (VP (VP (VBD arriv...
# 2        2  (ROOT (S (NP (PRP she)) (VP (VBD was) (RB not)...
# 3        3  (ROOT (S (NP (PRP she)) (VP (VBZ is) (VP (VBN ...
# 4        4  (ROOT (S (NP (DT the) (NN patient)) (VP (VBD f...
# ..     ...                                                ...
# 400    400  (ROOT (S (NP (DT The) (NN patient)) (VP (VBZ h...
# 401    401  (ROOT (S (NP (DT The) (NN patient)) (VP (VBZ h...
# 402    402  (ROOT (S (NP (DT The) (NN patient)) (VP (VBZ i...
# 403    403  (ROOT (S (NP (DT The) (NN patient)) (VP (VBD d...
# 404    404  (ROOT (S (NP (DT The) (NN patient)) (VP (VBD w...
#
#                                 sentence2_binary_parse  \
# 0                     ( she ( appeared unenergetic ) )
# 1    ( she ( ( ( ( ( ( ( arrived alert ) and ) orie...
# 2                   ( she ( ( was not ) ambulatory ) )
# 3    ( she ( is ( ( scheduled ( for ( a ( medical p...
# 4    ( ( the patient ) ( felt ( ( a sudden ) ( ( wo...
# ..                                                 ...
# 400  ( ( The patient ) ( ( has ( a ( clear X-ray ) ...
# 401        ( ( The patient ) ( ( has pneumonia ) . ) )
# 402  ( ( The patient ) ( ( is ( being ( treated ( f...
# 403  ( ( The patient ) ( ( ( did not ) ( receive br...
# 404     ( ( The patient ) ( ( was ( a smoker ) ) . ) )
#
#                                              sentence1  \
# 0         She arrived with her friend, very lethargic.
# 1         She arrived with her friend, very lethargic.
# 2         She arrived with her friend, very lethargic.
# 3    The patient was not acutely ill last night, so...
# 4    The patient was not acutely ill last night, so...
# ..                                                 ...
# 400  She was sent to the ER where a repeat CXR show...
# 401  She was sent to the ER where a repeat CXR show...
# 402  While on the floor he was started on azithromy...
# 403  While on the floor he was started on azithromy...
# 404  While on the floor he was started on azithromy...
#
#                                              sentence2  \
# 0                            she  appeared unenergetic
# 1     she arrived alert and oriented, energetic, in...
# 2                               she was not ambulatory
# 3       she is scheduled for a medical procedure today
# 4     the patient felt a sudden worsening in sympto...
# ..                                                 ...
# 400                    The patient has a clear X-ray.
# 401                        The patient has pneumonia.
# 402   The patient is being treated for a CHF exacer...
# 403      The patient did not receive bronchodilators.
# 404                         The patient was a smoker.
#
#                                           pairID  \
# 0    mediqa-6784509e-5ca1-11e9-8844-f45c89b91419
# 1    mediqa-678582f4-5ca1-11e9-af66-f45c89b91419
# 2    mediqa-67858838-5ca1-11e9-ad79-f45c89b91419
# 3    mediqa-67858ba8-5ca1-11e9-8a1f-f45c89b91419
# 4    mediqa-67858f54-5ca1-11e9-baa4-f45c89b91419
# ..                                           ...
# 400  mediqa-6789e518-5ca1-11e9-aca6-f45c89b91419
# 401  mediqa-6789e72c-5ca1-11e9-ad15-f45c89b91419
# 402  mediqa-6789eab6-5ca1-11e9-a462-f45c89b91419
# 403  mediqa-6789ed06-5ca1-11e9-b15f-f45c89b91419
# 404  mediqa-6789ef9a-5ca1-11e9-a2f1-f45c89b91419
#
#                                 sentence1_binary_parse  \
# 0    ( She ( ( ( ( arrived ( with ( her friend ) ) ...
# 1    ( She ( ( ( ( arrived ( with ( her friend ) ) ...
# 2    ( She ( ( ( ( arrived ( with ( her friend ) ) ...
# 3    ( ( ( ( ( ( The patient ) ( ( was not ) ( acut...
# 4    ( ( ( ( ( ( The patient ) ( ( was not ) ( acut...
# ..                                                 ...
# 400  ( She ( ( was ( sent ( to ( ( the ER ) ( where...
# 401  ( She ( ( was ( sent ( to ( ( the ER ) ( where...
# 402  ( ( While ( ( on ( the floor ) ) ( he ( was ( ...
# 403  ( ( While ( ( on ( the floor ) ) ( he ( was ( ...
# 404  ( ( While ( ( on ( the floor ) ) ( he ( was ( ...
#
#                                        sentence1_parse  \
# 0    (ROOT (S (NP (PRP She)) (VP (VBD arrived) (PP ...
# 1    (ROOT (S (NP (PRP She)) (VP (VBD arrived) (PP ...
# 2    (ROOT (S (NP (PRP She)) (VP (VBD arrived) (PP ...
# 3    (ROOT (S (S (NP (DT The) (NN patient)) (VP (VB...
# 4    (ROOT (S (S (NP (DT The) (NN patient)) (VP (VB...
# ..                                                 ...
# 400  (ROOT (S (NP (PRP She)) (VP (VBD was) (VP (VBN...
# 401  (ROOT (S (NP (PRP She)) (VP (VBD was) (VP (VBN...
# 402  (ROOT (SBAR (IN While) (S (PP (IN on) (NP (DT ...
# 403  (ROOT (SBAR (IN While) (S (PP (IN on) (NP (DT ...
# 404  (ROOT (SBAR (IN While) (S (PP (IN on) (NP (DT ...
#
#                                          pair_id          label
# 0    mediqa-6784509e-5ca1-11e9-8844-f45c89b91419     entailment
# 1    mediqa-678582f4-5ca1-11e9-af66-f45c89b91419  contradiction
# 2    mediqa-67858838-5ca1-11e9-ad79-f45c89b91419        neutral
# 3    mediqa-67858ba8-5ca1-11e9-8a1f-f45c89b91419     entailment
# 4    mediqa-67858f54-5ca1-11e9-baa4-f45c89b91419  contradiction
# ..                                           ...            ...
# 400  mediqa-6789e518-5ca1-11e9-aca6-f45c89b91419  contradiction
# 401  mediqa-6789e72c-5ca1-11e9-ad15-f45c89b91419        neutral
# 402  mediqa-6789eab6-5ca1-11e9-a462-f45c89b91419     entailment
# 403  mediqa-6789ed06-5ca1-11e9-b15f-f45c89b91419  contradiction
# 404  mediqa-6789ef9a-5ca1-11e9-a2f1-f45c89b91419        neutral
#
# [405 rows x 10 columns]
